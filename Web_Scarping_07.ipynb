# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=f24a2327-3f8c-40b8-b7f1-92fb05e60079&as-searchtext=lap'

# %%
res=requests.get(url)

# %%
res=res.content

# %%
soup=BeautifulSoup(res,'html.parser')

# %%
name=soup.find_all('div',class_='_4rR01T')

# %%
prn=[]
for i in range(0,len(name)):
  prn.append(name[i].get_text())

# %%
rating=soup.find_all('div',class_='_3LWZlK')

# %%
rat=[]
for i in range(0,len(rating)):
  rat.append(rating[i].get_text())

# %%
df=pd.DataFrame()

# %%
df['Product']=prn

# %%
df2 = pd.DataFrame({'A':rat})

# %%
df= df.append(df2)
# Out:
# <ipython-input-32-5ac25e231d4c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(df2)

# %%
df
# Out:
#                                               Product    A
# 0   HP Chromebook x360 Intel Celeron Quad Core N40...  NaN
# 1   Infinix INBook X2 Plus Core i5 11th Gen 1155G7...  NaN
# 2   ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  NaN
# 3   ASUS Vivobook 15 Core i5 11th Gen 1135G7 - (8 ...  NaN
# 4   Lenovo V15 Ryzen 5 Hexa Core 5500U - (8 GB/512...  NaN
# ..                                                ...  ...
# 34                                                NaN    2
# 35                                                NaN    5
# 36                                                NaN  4.1
# 37                                                NaN    5
# 38                                                NaN    1
#
# [165 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup
url='https://www.flipkart.com/asus-vivobook-15-core-i3-11th-gen-1115g4-8-gb-512-gb-ssd-windows-11-home-x515ea-ej322ws-x515ea-ej328ws-thin-light-laptop/p/itmaafbc240a8774?pid=COMGA5TUCZAV4HGH&lid=LSTCOMGA5TUCZAV4HGHWM8PS0&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&spotlightTagId=BestsellerId_6bo%2Fb5g&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=search-autosuggest&iid=471fb073-63b5-4780-a552-9ddaedcd6622.COMGA5TUCZAV4HGH.SEARCH&ppt=sp&ppn=sp&qH=312f91285e048e09'
response = requests.get(url)
response=response.content

# %%
        soup = BeautifulSoup(response, 'html.parser')
        product_title = soup.find('span', {'class': 'B_NuCI'}).text.strip()
        product_price = soup.find('div', {'class': '_30jeq3'}).text.strip()
        product_ratings = soup.find('div', {'class': '_3LWZlK'}).text.strip()
        product_reviews = []
        review_elements = soup.find_all('div', {'class': 'col _2wzgFH'})
        for review_element in review_elements:
            review_text = review_element.find('div', {'class': 't-ZTKy'}).text.strip()
            product_reviews.append(review_text)
        product_details = {
            'Title': product_title,
            'Price': product_price,
            'Ratings': product_ratings,
            'Reviews': product_reviews
        }
# Out:
# {'Title': 'ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS | X515EA-EJ328WS Thin and Light Laptop\xa0\xa0(15.6 Inch, Transparent Silver, 1.80 kg, With MS Office)', 'Price': '₹34,990', 'Ratings': '4.3', 'Reviews': ['Just amazing. Performance is very good.READ MORE', 'Awesome! Thanks for FlipkartREAD MORE', 'Its really awesome👍👏😊......READ MORE', "Over all review not bad It's worth of money 👍READ MORE", 'This is awesome. I love itREAD MORE', 'Best laptop this price segment ❤️❤️🤘  This is my first laptopREAD MORE', 'Value for moneyBattery drained fastREAD MORE', 'Nice product ☺️READ MORE', 'Very nice and great product.  Performance is very good.Very good product in this price range.Games, video editing is very good.But the battery does not have a long charge time.READ MORE', 'Go for it.It is working smoothly right now.if there will be any problems come.i will update it hereREAD MORE']}

# %%
import pandas as pd

# %%
df=pd.DataFrame(product_details)

# %%
df
# Out:
#                                                Title    Price Ratings  \
# 0  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 1  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 2  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 3  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 4  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 5  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 6  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 7  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 8  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
# 9  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹34,990     4.3
#
#                                              Reviews
# 0   Just amazing. Performance is very good.READ MORE
# 1              Awesome! Thanks for FlipkartREAD MORE
# 2               Its really awesome👍👏😊......READ MORE
# 3  Over all review not bad It's worth of money 👍R...
# 4                This is awesome. I love itREAD MORE
# 5  Best laptop this price segment ❤️❤️🤘  This is ...
# 6       Value for moneyBattery drained fastREAD MORE
# 7                           Nice product ☺️READ MORE
# 8  Very nice and great product.  Performance is v...
# 9  Go for it.It is working smoothly right now.if ...

# %%
df.to_csv('Laptop.csv')
